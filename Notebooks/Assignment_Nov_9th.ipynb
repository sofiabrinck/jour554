# %% [markdown]
# ## Assignment November 9th

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd

# %%
census_df = gpd.read_file("Census_Blocks_2020.geojson")
# Out:
# D:\Anaconda\lib\site-packages\geopandas\array.py:85: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
census_df.plot()
# Out:
# D:\Anaconda\lib\site-packages\geopandas\plotting.py:38: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# D:\Anaconda\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# D:\Anaconda\lib\site-packages\descartes\patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# <AxesSubplot:>

# %%
census_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 91627 entries, 0 to 91626
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   objectid       91627 non-null  int64
#  1   state          91627 non-null  object
#  2   county         91627 non-null  object
#  3   ct20           91627 non-null  object
#  4   bg20           91627 non-null  object
#  5   cb20           91627 non-null  object
#  6   ctcb20         91627 non-null  object
#  7   feat_type      91627 non-null  object
#  8   fip20          91627 non-null  object
#  9   bgfip20        91627 non-null  object
#  10  city           91627 non-null  object
#  11  comm           91627 non-null  object
#  12  citycomm       91627 non-null  object
#  13  zcta20         91473 non-null  object
#  14  hd12           91483 non-null  float64
#  15  hd_name        91483 non-null  object
#  16  spa12          91483 non-null  float64
# ...

# %%
census_df.columns = census_df.columns.str.lower()

# %%
census_df.head()
# Out:
#    objectid state county    ct20     bg20  cb20      ctcb20 feat_type  fip20  \
# 0         1    06    037  109300  1093002  2015  1093002015      Land  44000
# 1         2    06    037  109300  1093001  1007  1093001007      Land  44000
# 2         3    06    037  111100  1111001  1005  1111001005      Land  44000
# 3         4    06    037  111202  1112023  3009  1112023009      Land  44000
# 4         5    06    037  113101  1131011  1011  1131011011      Land  44000
#
#         bgfip20  ... spa12      spa_name sup11   sup_label  pop20 sup21  \
# 0  109300244000  ...   2.0  San Fernando     3  District 3     80  None
# 1  109300144000  ...   2.0  San Fernando     3  District 3     63  None
# 2  111100144000  ...   2.0  San Fernando     5  District 5     56  None
# 3  111202344000  ...   2.0  San Fernando     5  District 5     99  None
# 4  113101144000  ...   2.0  San Fernando     5  District 5    242  None
#
#    housing20   shapestarea shapestlength  \
# ...

# %%
census_df.to_file(r"C:\Users\Sofía Brinck\Jupyter_Notebooks\Maps\census_df.geojson", driver="GeoJSON")
