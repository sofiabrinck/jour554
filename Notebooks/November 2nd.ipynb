# %% [markdown]
# ## Assignment Nov. 2nd, Sofia Brinck

# %%
# %load_ext lab_black
import pandas as pd

# %%
url_politics = "https://www.realclearpolitics.com/epolls/other/kamala_harris_favorableunfavorable-6690.html#polls"

# %%
page_politics = pd.read_html(url_politics, attrs={"class": "data large"})

# %%
df_politics = pd.DataFrame(page_politics[1])
df_politics
# Out:
#                                  Poll           Date   Sample  Favorable  \
# 0                         RCP Average   9/15 - 10/26       --       42.5
# 1              Economist/YouGovYouGov  10/24 - 10/26  1261 RV       43.0
# 2    Politico/Morning ConsultPolitico  10/22 - 10/24  1999 RV       42.0
# 3                    FOX NewsFOX News  10/16 - 10/19  1003 RV       44.0
# 4              Economist/YouGovYouGov  10/16 - 10/19  1268 RV       42.0
# ..                                ...            ...      ...        ...
# 219            Economist/YouGovYouGov    1/27 - 1/29  1313 RV       35.0
# 220  Politico/Morning ConsultPolitico    1/25 - 1/27  1997 RV       25.0
# 221  Politico/Morning ConsultPolitico    1/18 - 1/22  1996 RV       24.0
# 222              QuinnipiacQuinnipiac  12/12 - 12/17  1147 RV       20.0
# 223                            CNNCNN      9/6 - 9/9   923 RV       22.0
#
#      Unfavorable Spread
# 0           51.0   -8.5
# 1           50.0     -7
# ...

# %%
df_politics.head()
# Out:
#                                Poll           Date   Sample  Favorable  \
# 0                       RCP Average   9/15 - 10/26       --       42.5
# 1            Economist/YouGovYouGov  10/24 - 10/26  1261 RV       43.0
# 2  Politico/Morning ConsultPolitico  10/22 - 10/24  1999 RV       42.0
# 3                  FOX NewsFOX News  10/16 - 10/19  1003 RV       44.0
# 4            Economist/YouGovYouGov  10/16 - 10/19  1268 RV       42.0
#
#    Unfavorable Spread
# 0         51.0   -8.5
# 1         50.0     -7
# 2         50.0     -8
# 3         54.0    -10
# 4         53.0    -11

# %%
df_politics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Poll         224 non-null    object
#  1   Date         224 non-null    object
#  2   Sample       224 non-null    object
#  3   Favorable    224 non-null    float64
#  4   Unfavorable  224 non-null    float64
#  5   Spread       224 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 10.6+ KB

# %%
df_politics.columns = df_politics.columns.str.lower()

# %%
df_politics.head()
# Out:
#                                poll           date   sample  favorable  \
# 0                       RCP Average   9/15 - 10/26       --       42.5
# 1            Economist/YouGovYouGov  10/24 - 10/26  1261 RV       43.0
# 2  Politico/Morning ConsultPolitico  10/22 - 10/24  1999 RV       42.0
# 3                  FOX NewsFOX News  10/16 - 10/19  1003 RV       44.0
# 4            Economist/YouGovYouGov  10/16 - 10/19  1268 RV       42.0
#
#    unfavorable spread
# 0         51.0   -8.5
# 1         50.0     -7
# 2         50.0     -8
# 3         54.0    -10
# 4         53.0    -11

# %%
df_politics.drop(["sample"], axis=1, inplace=True)

# %%
df_politics.head()
# Out:
#                                poll           date  favorable  unfavorable  \
# 0                       RCP Average   9/15 - 10/26       42.5         51.0
# 1            Economist/YouGovYouGov  10/24 - 10/26       43.0         50.0
# 2  Politico/Morning ConsultPolitico  10/22 - 10/24       42.0         50.0
# 3                  FOX NewsFOX News  10/16 - 10/19       44.0         54.0
# 4            Economist/YouGovYouGov  10/16 - 10/19       42.0         53.0
#
#   spread
# 0   -8.5
# 1     -7
# 2     -8
# 3    -10
# 4    -11

# %%
df_politics.rename(columns={"favorable": "fav", "unfavorable": "unfav"}, inplace=True)

# %%
df_politics.head()
# Out:
#                                poll           date   fav  unfav spread
# 0                       RCP Average   9/15 - 10/26  42.5   51.0   -8.5
# 1            Economist/YouGovYouGov  10/24 - 10/26  43.0   50.0     -7
# 2  Politico/Morning ConsultPolitico  10/22 - 10/24  42.0   50.0     -8
# 3                  FOX NewsFOX News  10/16 - 10/19  44.0   54.0    -10
# 4            Economist/YouGovYouGov  10/16 - 10/19  42.0   53.0    -11

# %%
df_politics.sort_values("fav", ascending=False).head(10)
# Out:
#                                  poll         date   fav  unfav spread
# 131              Reuters/IpsosReuters  9/11 - 9/15  58.0   43.0    +15
# 79   Politico/Morning ConsultPolitico  2/14 - 2/15  57.0   36.0    +21
# 118              Reuters/IpsosReuters  10/2 - 10/6  56.0   43.0    +13
# 116                  FOX NewsFOX News  10/3 - 10/6  54.0   40.0    +14
# 70   Politico/Morning ConsultPolitico  3/12 - 3/15  54.0   37.0    +17
# 85   Politico/Morning ConsultPolitico  1/22 - 1/25  54.0   38.0    +16
# 98                   FOX NewsFOX News  12/6 - 12/9  54.0   42.0    +12
# 82   Politico/Morning ConsultPolitico   1/29 - 2/1  53.0   39.0    +14
# 63   Politico/Morning ConsultPolitico    4/2 - 4/4  53.0   39.0    +14
# 133                  FOX NewsFOX News   9/7 - 9/10  53.0   44.0     +9

# %%
df_politics.sort_values("spread", ascending=False).head(10)
# Out:
#                                  poll           date   fav  unfav spread
# 200              Harvard-HarrisHarris    5/29 - 5/30  33.0   33.0    Tie
# 192                            CNNCNN    6/28 - 6/30  35.0   35.0    Tie
# 36   Politico/Morning ConsultPolitico     7/9 - 7/12  47.0   47.0    Tie
# 113     NBC News/Wall St. JrnlNBC/WSJ   10/9 - 10/12  41.0   41.0    Tie
# 107     NBC News/Wall St. JrnlNBC/WSJ  10/29 - 10/31  42.0   42.0    Tie
# 39   Politico/Morning ConsultPolitico    6/25 - 6/28  46.0   46.0    Tie
# 42               Harvard-HarrisHarris    6/15 - 6/17  43.0   43.0    Tie
# 103              Harvard-HarrisHarris  11/17 - 11/19  45.0   45.0    Tie
# 90             Economist/YouGovYouGov    1/10 - 1/12  47.0   47.0    Tie
# 89      NBC News/Wall St. JrnlNBC/WSJ    1/10 - 1/13  41.0   41.0    Tie

# %%
df_politics["spread"].replace({"Tie": "0"}, inplace=True)

# %%
df_politics.sort_values("spread", ascending=True).head(20)
# Out:
#                                  poll           date   fav  unfav spread
# 50             Economist/YouGovYouGov    5/15 - 5/18  47.0   46.0     +1
# 147  Politico/Morning ConsultPolitico    8/14 - 8/16  42.0   41.0     +1
# 56             Economist/YouGovYouGov    4/25 - 4/27  47.0   46.0     +1
# 47             Economist/YouGovYouGov    5/22 - 5/25  49.0   48.0     +1
# 134            Economist/YouGovYouGov      9/6 - 9/8  49.0   48.0     +1
# 130            Economist/YouGovYouGov    9/13 - 9/15  48.0   47.0     +1
# 185                  FOX NewsFOX News    8/11 - 8/15  41.0   40.0     +1
# 99             Economist/YouGovYouGov    12/6 - 12/8  44.0   43.0     +1
# 46             Economist/YouGovYouGov     5/29 - 6/1  47.0   46.0     +1
# 203              Harvard-HarrisHarris     4/30 - 5/1  34.0   33.0     +1
# 123            Economist/YouGovYouGov    9/27 - 9/30  47.0   46.0     +1
# 40             Economist/YouGovYouGov    6/20 - 6/22  48.0   47.0     +1
# ...

# %%
# I know there are problems with the spread column, because it's an object and not an integer, but I can't figure out how to change it.

# %%
df_politics.to_csv("C:\Users\Sofía Brinck\Jupyter_Notebooks\Assignments\November_2nd_ass")
