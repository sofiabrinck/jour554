# %% [markdown]
# # October 12th assignment

# %%
import pandas as pd

# %%
df = pd.read_csv ("Hate_decade.csv")

# %%
df.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence  County NCIC  \
# 0  CA01-0000000001        2001                2       1  100
# 1  CA01-0000000005        2001                2       1  100
# 2  CA01-0000000003        2001                5       1  100
# 3  CA01-0000000002        2001                9       1  100
# 4  CA01-0000000004        2001                9       1  100
#
#    TotalNumberOfVictims  TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 0                     1                               1                White
# 1                     2                               2                White
# 2                     1                               1                White
# 3                     1                               1                White
# 4                     2                               2                White
#
#    TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 0                      2                Simple Assault  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24436 entries, 0 to 24435
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   RecordId                                24436 non-null  object
#  1   ClosedYear                              24436 non-null  int64
#  2   MonthOccurrence                         24436 non-null  int64
#  3   County                                  24436 non-null  int64
#  4   NCIC                                    24436 non-null  object
#  5   TotalNumberOfVictims                    24436 non-null  int64
#  6   TotalNumberOfIndividualVictims          24436 non-null  int64
#  7   SuspectsRaceAsAGroup                    24436 non-null  object
#  8   TotalNumberOfSuspects                   24436 non-null  int64
#  9   MostSeriousUcr                          24436 non-null  object
# ...

# %% [markdown]
# ### Hate crimes by race where perpetrators are white in Los Angeles County

# %%
df [(df["MostSeriousBiasType"] == "Race/Ethnicity/Ancestry") \
 & (df["SuspectsRaceAsAGroup"] == "White")
   & (df["County"] == 19)]
# Out:
#               RecordId  ClosedYear  MonthOccurrence  County  NCIC  \
# 197    CA01-0000000204        2001                2      19  1900
# 198    CA01-0000000202        2001                3      19  1900
# 199    CA01-0000000208        2001                3      19  1900
# 201    CA01-0000000210        2001                3      19  1900
# 204    CA01-0000000216        2001                3      19  1900
# ...                ...         ...              ...     ...   ...
# 24408  CA00-0000035141        2020                6      19  1965
# 24410  CA00-0000035144        2020                3      19  1965
# 24416  CA00-0000035150        2020               11      19  1949
# 24423  CA00-0000035157        2020               12      19  191R
# 24424  CA00-0000035158        2020               12      19  1900
#
#        TotalNumberOfVictims  TotalNumberOfIndividualVictims  \
# 197                       2                               2
# ...

# %%
white_crimes_LA = [(df["MostSeriousBiasType"] == "Race/Ethnicity/Ancestry") \
 & (df["SuspectsRaceAsAGroup"] == "White")
   & (df["County"] == 19)]

# %%
len(white_crimes_LA)
# Out:
# 1

# %% [markdown]
# (I tried to count the rows but I am not sure why the result is just 1)
